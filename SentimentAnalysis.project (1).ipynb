# %%
! pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\mourya\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\mourya\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\mourya\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\mourya\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\mourya\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\mourya\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %% [markdown]
# ## Import the data
#
# Link to data - https://www.kaggle.com/datasets/mdismielhossenabir/sentiment-analysis/data

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('sentiment_analysis.csv')

# %%
df
# Out:
#      Year  Month  Day Time of Tweet  \
# 0    2018      8   18       morning
# 1    2018      8   18          noon
# 2    2017      8   18         night
# 3    2022      6    8       morning
# 4    2022      6    8          noon
# ..    ...    ...  ...           ...
# 494  2015     10   18         night
# 495  2021      2   25       morning
# 496  2022      5   30          noon
# 497  2018      8   10         night
# 498  2019      3   25       morning
#
#                                                   text sentiment     Platform
# 0                What a great day!!! Looks like dream.  positive    Twitter
# 1       I feel sorry, I miss you here in the sea beach  positive    Facebook
# 2                                       Don't angry me  negative     Facebook
# 3    We attend in the class just for listening teac...  negative    Facebook
# 4                    Those who want to go, let them go  negative   Instagram
# ..                                                 ...       ...          ...
# 494  According to , a quarter of families under six...  negative     Twitter
# 495      the plan to not spend money is not going well  negative   Instagram
# 496    uploading all my bamboozle pictures of facebook   neutral    Facebook
# 497   congratulations ! you guys finish a month ear...  positive     Twitter
# 498   actually, I wish I was back in Tahoe.  I miss...  negative   Instagram
#
# [499 rows x 7 columns]

# %%
df['sentiment'].unique()
# Out:
# array(['positive', 'negative', 'neutral'], dtype=object)

# %%
df['sentiment'].value_counts()
# Out:
# neutral     199
# positive    166
# negative    134
# Name: sentiment, dtype: int64

# %%
df = df[['text','sentiment']]

# %%
df
# Out:
#                                                   text sentiment
# 0                What a great day!!! Looks like dream.  positive
# 1       I feel sorry, I miss you here in the sea beach  positive
# 2                                       Don't angry me  negative
# 3    We attend in the class just for listening teac...  negative
# 4                    Those who want to go, let them go  negative
# ..                                                 ...       ...
# 494  According to , a quarter of families under six...  negative
# 495      the plan to not spend money is not going well  negative
# 496    uploading all my bamboozle pictures of facebook   neutral
# 497   congratulations ! you guys finish a month ear...  positive
# 498   actually, I wish I was back in Tahoe.  I miss...  negative
#
# [499 rows x 2 columns]

# %% [markdown]
# ## using Vader and SIA

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
sentence = "This movie was amazing, but the acting was a bit disappointing."
sentiment_scores = sia.polarity_scores(sentence)
print(sentiment_scores)
# Out:
# {'neg': 0.293, 'neu': 0.544, 'pos': 0.163, 'compound': -0.4404}
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\MOURYA\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
def analyze_sentiment_nltk(review):
    score = sia.polarity_scores(review)
    final_score = score['compound']
    if final_score > 0.4:
        return 'positive'
    elif final_score >= -0.3 and final_score <= 0.4:
        return 'neutral'
    else :
        return 'negative'

# %%
df['predicted_sentiment_nltk'] = df['text'].apply(analyze_sentiment_nltk)
# Out:
# C:\Users\MOURYA\AppData\Local\Temp\ipykernel_1208\855690513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['predicted_sentiment_nltk'] = df['text'].apply(analyze_sentiment_nltk)

# %%
df
# Out:
#                                                   text sentiment  \
# 0                What a great day!!! Looks like dream.  positive
# 1       I feel sorry, I miss you here in the sea beach  positive
# 2                                       Don't angry me  negative
# 3    We attend in the class just for listening teac...  negative
# 4                    Those who want to go, let them go  negative
# ..                                                 ...       ...
# 494  According to , a quarter of families under six...  negative
# 495      the plan to not spend money is not going well  negative
# 496    uploading all my bamboozle pictures of facebook   neutral
# 497   congratulations ! you guys finish a month ear...  positive
# 498   actually, I wish I was back in Tahoe.  I miss...  negative
#
#     predicted_sentiment_nltk
# 0                   positive
# 1                    neutral
# 2                   positive
# 3                    neutral
# 4                    neutral
# ..                       ...
# 494                 negative
# 495                  neutral
# 496                 negative
# 497                 positive
# 498                  neutral
#
# [499 rows x 3 columns]

# %%
df['prediction_correctness_nltk'] = np.where(df['sentiment']==df['predicted_sentiment_nltk'],1,0)
# Out:
# C:\Users\1034590\AppData\Local\Temp\ipykernel_19600\1528029338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prediction_correctness_nltk'] = np.where(df['sentiment']==df['predicted_sentiment_nltk'],1,0)

# %%
df
# Out:
#                                                   text sentiment  \
# 0                What a great day!!! Looks like dream.  positive
# 1       I feel sorry, I miss you here in the sea beach  positive
# 2                                       Don't angry me  negative
# 3    We attend in the class just for listening teac...  negative
# 4                    Those who want to go, let them go  negative
# ..                                                 ...       ...
# 494  According to , a quarter of families under six...  negative
# 495      the plan to not spend money is not going well  negative
# 496    uploading all my bamboozle pictures of facebook   neutral
# 497   congratulations ! you guys finish a month ear...  positive
# 498   actually, I wish I was back in Tahoe.  I miss...  negative
#
#     predicted_sentiment_nlt
/s eta 0:00:00
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.5 MB 435.7 kB/s eta 0:00:04
#    - -------------------------------------- 0.1/1.5 MB 544.7 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.5 MB 656.4 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.5 MB 656.4 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.5 MB 656.4 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.5 MB 656.4 kB/s eta 0:00:03
#    --- ------------------------------------ 0.1/1.5 MB 405.9 kB/s eta 0:00:04
#    ---- ----------------------------------- 0.2/1.5 MB 382.3 kB/s eta 0:00:04
#    ---- ----------------------------------- 0.2/1.5 MB 382.3 kB/s eta 0:00:04
#    ----- ---------------------------------- 0.2/1.5 MB 406.9 kB/s eta 0:00:04
#    ----- ---------------------------------- 0.2/1.5 MB 402.0 kB/s eta 0:00:04
#    ----- ---------------------------------- 0.2/1.5 MB 402.0 kB/s eta 0:00:04
#    ----- ---------------------------------- 0.2/1.5 MB 402.0 kB/s eta 0:00:04
#    ------ --------------------------------- 0.3/1.5 MB 365.7 kB/s eta 0:00:04
#    ------- -------------------------------- 0.3/1.5 MB 384.5 kB/s eta 0:00:04
#    -------- ------------------------------- 0.3/1.5 MB 401.6 kB/s eta 0:00:03
#    -------- ------------------------------- 0.3/1.5 MB 428.3 kB/s eta 0:00:03
#    -------- ------------------------------- 0.3/1.5 MB 428.3 kB/s eta 0:00:03
#    -------- ------------------------------- 0.3/1.5 MB 428.3 kB/s eta 0:00:03
#    --------- ------------------------------ 0.4/1.5 MB 382.5 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.4/1.5 MB 385.0 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.4/1.5 MB 377.4 kB/s eta 0:00:03
#    ------------ --------------------------- 0.5/1.5 MB 421.2 kB/s eta 0:00:03
#    ------------ --------------------------- 0.5/1.5 MB 430.6 kB/s eta 0:00:03
#    ------------ --------------------------- 0.5/1.5 MB 430.6 kB/s eta 0:00:03
#    ------------ --------------------------- 0.5/1.5 MB 430.6 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 398.3 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 398.3 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 376.7 kB/s eta 0:00:03
#    -------------- ------------------------- 0.6/1.5 MB 386.0 kB/s eta 0:00:03
#    -------------- ------------------------- 0.6/1.5 MB 386.0 kB/s eta 0:00:03
#    -------------- ------------------------- 0.6/1.5 MB 386.0 kB/s eta 0:00:03
#    -------------- ------------------------- 0.6/1.5 MB 357.4 kB/s eta 0:00:03
#    -------------- ------------------------- 0.6/1.5 MB 357.4 kB/s eta 0:00:03
#    -------------- ------------------------- 0.6/1.5 MB 357.4 kB/s eta 0:00:03
#    -------------- ------------------------- 0.6/1.5 MB 357.4 kB/s eta 0:00:03
#    -------------- ------------------------- 0.6/1.5 MB 357.4 kB/s eta 0:00:03
#    -------------- ------------------------- 0.6/1.5 MB 357.4 kB/s eta 0:00:03
#    -------------- ------------------------- 0.6/1.5 MB 357.4 kB/s eta 0:00:03
#    -------------- ------------------------- 0.6/1.5 MB 357.4 kB/s eta 0:00:03
#    -------------- ------------------------- 0.6/1.5 MB 357.4 kB/s eta 0:00:03
#    -------------- ------------------------- 0.6/1.5 MB 357.4 kB/s eta 0:00:03
#    --------------- ------------------------ 0.6/1.5 MB 284.6 kB/s eta 0:00:04
#    ---------------- ----------------------- 0.6/1.5 MB 288.0 kB/s eta 0:00:04
#    ---------------- ----------------------- 0.6/1.5 MB 288.0 kB/s eta 0:00:04
#    ---------------- ----------------------- 0.6/1.5 MB 282.3 kB/s eta 0:00:04
#    ---------------- ----------------------- 0.6/1.5 MB 285.6 kB/s eta 0:00:04
#    ----------------- ---------------------- 0.6/1.5 MB 286.1 kB/s eta 0:00:04
#    ------------------ --------------------- 0.7/1.5 MB 294.2 kB/s eta 0:00:03
#    ------------------- -------------------- 0.7/1.5 MB 305.8 kB/s eta 0:00:03
#    -------------------- ------------------- 0.8/1.5 MB 321.3 kB/s eta 0:00:03
#    -------------------- ------------------- 0.8/1.5 MB 321.3 kB/s eta 0:00:03
#    --------------------- ------------------ 0.8/1.5 MB 323.5 kB/s eta 0:00:03
#    ----------------------- ---------------- 0.9/1.5 MB 343.9 kB/s eta 0:00:02
#    ------------------------- -------------- 0.9/1.5 MB 361.5 kB/s eta 0:00:02
#    --------------------------- ------------ 1.0/1.5 MB 386.2 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.1/1.5 MB 410.1 kB/s eta 0:00:01
#    ------------------------------- -------- 1.2/1.5 MB 425.6 kB/s eta 0:00:01
#    --------------------------------- ------ 1.2/1.5 MB 448.1 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.3/1.5 MB 466.1 kB/s eta 0:00:01
#    ------------------------------------- -- 1.4/1.5 MB 487.1 kB/s eta 0:00:01
#    -------------------------------------- - 1.4/1.5 MB 490.6 kB/s eta 0:00:01
#    ---------------------------------------  1.5/1.5 MB 496.7 kB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 498.4 kB/s eta 0:00:00
# Installing collected packages: nltk, textblob
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
# Successfully installed nltk-3.9.1 textblob-0.19.0

# %%
from textblob import TextBlob

# %%
def analyze_sentiment_textblob(review):
    blob = TextBlob(review)
    if blob.sentiment.polarity >= 0.4:
        return 'positive'
    elif blob.sentiment.polarity >= -0.3 and blob.sentiment.polarity <= 0.4:
        return 'neutral'
    else : 
        return 'negative'

# %%
analyze_sentiment_textblob('This happens to be a nice restaurent ')
# Out:
# 'positive'

# %%
df['predicted_sentiment_textblob'] = df['text'].apply(analyze_sentiment_textblob)
# Out:
# C:\Users\MOURYA\AppData\Local\Temp\ipykernel_1208\3547837887.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['predicted_sentiment_textblob'] = df['text'].apply(analyze_sentiment_textblob)

# %%
df['prediction_correctness_textblob'] = np.where(df['sentiment']==df['predicted_sentiment_textblob'],1,0)
# Out:
# C:\Users\MOURYA\AppData\Local\Temp\ipykernel_1208\4004997036.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prediction_correctness_textblob'] = np.where(df['sentiment']==df['predicted_sentiment_textblob'],1,0)

# %%
df
# Out:
#                                                   text sentiment  \
# 0                What a great day!!! Looks like dream.  positive
# 1       I feel sorry, I miss you here in the sea beach  positive
# 2                                       Don't angry me  negative
# 3    We attend in the class just for listening teac...  negative
# 4                    Those who want to go, let them go  negative
# ..                                                 ...       ...
# 494  According to , a quarter of families under six...  negative
# 495      the plan to not spend money is not going well  negative
# 496    uploading all my bamboozle pictures of facebook   neutral
# 497   congratulations ! you guys finish a month ear...  positive
# 498   actually, I wish I was back in Tahoe.  I miss...  negative
#
#     predicted_sentiment_nltk  prediction_correctness_nltk  \
# 0                   positive                            1
# 1                    neutral                            0
# 2                   positive                            0
# 3                    neutral                            0
# 4                    neutral                            0
# ..                       ...                          ...
# 494                 negative                            1
# 495                  neutral                            0
# 496                 negative                            0
# 497                 positive                            1
# 498                  neutral                            0
#
#     predicted_sentiment_textblob  prediction_correctness_textblob
# 0                       positive                                1
# 1                       negative                                0
# 2                       negative                                1
# 3                        neutral                                0
# 4                        neutral                                0
# ..                           ...                              ...
# 494                      neutral                                0
# 495                      neutral                                0
# 496                      neutral                                1
# 497                      neutral                                0
# 498                      neutral                                0
#
# [499 rows x 6 columns]

# %%
df['prediction_correctness_textblob'].value_counts()
# Out:
# 1    283
# 0    216
# Name: prediction_correctness_textblob, dtype: int64

# %%
df
# Out:
#                                                   text sentiment  \
# 0                What a great day!!! Looks like dream.  positive
# 1       I feel sorry, I miss you here in the sea beach  positive
# 2                                       Don't angry me  negative
# 3    We attend in the class just for listening teac...  negative
# 4                    Those who want to go, let them go  negative
# ..                                                 ...       ...
# 494  According to , a quarter of families under six...  negative
# 495      the plan to not spend money is not going well  negative
# 496    uploading all my bamboozle pictures of facebook   neutral
# 497   congratulations ! you guys finish a month ear...  positive
# 498   actually, I wish I was back in Tahoe.  I miss...  negative
#
#     predicted_sentiment_nltk predicted_sentiment_textblob  \
# 0                   positive                     positive
# 1                    neutral                     negative
# 2                   positive                     negative
# 3                    neutral                      neutral
# 4                    neutral                      neutral
# ..                       ...                          ...
# 494                 negative                      neutral
# 495                  neutral                      neutral
# 496                 negative                      neutral
# 497                 positive                      neutral
# 498                  neutral                      neutral
#
#      prediction_correctness_textblob
# 0                                  1
# 1                                  0
# 2                                  1
# 3                                  0
# 4                                  0
# ..                               ...
# 494                                0
# 495                                0
# 496                                1
# 497                                0
# 498                                0
#
# [499 rows x 5 columns]
